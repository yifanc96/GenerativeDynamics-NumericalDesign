# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.utils.data
from torch.utils.data import DataLoader 
from PIL import Image
from matplotlib import pyplot as plt
import seaborn as sns
import wandb
import math
import argparse
import datetime
import math
from time import time

# %%
res = 128
home = "/home/yc3400/scratch_research/gitrepo/GenerativeDynamics-NumericalDesign/Allen-Cahn/results/"
arrk = torch.load(home + f"AllenCahn-res{res}-kvals.pt")
arrtruth = torch.load(home + f"AllenCahn-res{res}-truth.pt")
arrRK10 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK10.pt") 
arrRK20 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK20.pt") 
arrRK40 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK40.pt")
arrspectrumRK5 = torch.load(home + f"AllenCahn-res{res}-spectrum-noise-RK5.pt")
# Out:
# /state/partition1/job-63539340/ipykernel_3609908/876499780.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrk = torch.load(home + f"AllenCahn-res{res}-kvals.pt")
# ...

# %%
plt.figure(figsize=(6, 6))
markers = ['o', 's', '^', 'd', 'v']

plt.plot(arrk, arrtruth, 'o-', marker=markers[0], markersize=8, markevery=5, linestyle='-', label="truth", linewidth=2)
plt.plot(arrk, arrspectrumRK5, 'o-', marker=markers[4], markersize=8, markevery=5, linestyle='-', label="spectrum-noise-RK5steps", linewidth=2)
plt.plot(arrk, arrRK10, 'o-', marker=markers[1], markersize=8, markevery=5, linestyle='-', label="white-noise-RK10steps", linewidth=2)
plt.plot(arrk, arrRK20, 'o-', marker=markers[2], markersize=8, markevery=5, linestyle='-', label="white-noise-RK20steps", linewidth=2)
plt.plot(arrk, arrRK40, 'o-', marker=markers[3], markersize=8, markevery=5, linestyle='-', label="white-noise-RK40steps", linewidth=2)

# plt.xlabel("k", fontsize=12)
# plt.title("Energy spectrum", fontsize=14)
plt.legend(fontsize=16, loc='upper right')
plt.grid(alpha=0.3)
plt.xscale('log', base = 2)
plt.yscale('log')
plt.tick_params(axis='both', which='major', labelsize=20)  # Change 14 to your desired size
plt.locator_params(axis='x', numticks=7)  # Adjust number as needed

plt.tight_layout()
plt.savefig(f"AllenCahn-res{res}-vs-spectrum-noise-energy spectrum.pdf", dpi=300)
# Out:
# /state/partition1/job-63539340/ipykernel_3609908/4006956171.py:4: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(arrk, arrtruth, 'o-', marker=markers[0], markersize=8, markevery=5, linestyle='-', label="truth", linewidth=2)
# /state/partition1/job-63539340/ipykernel_3609908/4006956171.py:4: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(arrk, arrtruth, 'o-', marker=markers[0], markersize=8, markevery=5, linestyle='-', label="truth", linewidth=2)
# /state/partition1/job-63539340/ipykernel_3609908/4006956171.py:5: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
# ...

# %%
res = 64
home = "/home/yc3400/scratch_research/gitrepo/GenerativeDynamics-NumericalDesign/Allen-Cahn/results/"
arrk = torch.load(home + f"AllenCahn-res{res}-kvals.pt")
arrtruth = torch.load(home + f"AllenCahn-res{res}-truth.pt")
arrRK10 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK10.pt") 
arrRK20 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK20.pt") 
arrspectrumRK5 = torch.load(home + f"AllenCahn-res{res}-spectrum-noise-RK5.pt")


plt.figure(figsize=(6, 6))
markers = ['o', 's', '^', 'd', 'v']

plt.plot(arrk, arrtruth, 'o-', marker=markers[0], markersize=8, markevery=5, linestyle='-', label="truth", linewidth=2)
plt.plot(arrk, arrspectrumRK5, 'o-', marker=markers[4], markersize=8, markevery=5, linestyle='-', label="spectrum-noise-RK5steps", linewidth=2)
plt.plot(arrk, arrRK10, 'o-', marker=markers[1], markersize=8, markevery=5, linestyle='-', label="white-noise-RK10steps", linewidth=2)
plt.plot(arrk, arrRK20, 'o-', marker=markers[2], markersize=8, markevery=5, linestyle='-', label="white-noise-RK20steps", linewidth=2)
# plt.plot(arrk, arrRK40, 'o-', marker=markers[3], markersize=8, markevery=5, linestyle='-', label="linear-RK40steps", linewidth=2)

# plt.xlabel("k", fontsize=12)
# plt.title("Energy spectrum", fontsize=14)
plt.legend(fontsize=16, loc='upper right')
plt.grid(alpha=0.3)
plt.xscale('log', base = 2)
plt.yscale('log')
plt.tick_params(axis='both', which='major', labelsize=20)  # Change 14 to your desired size
plt.locator_params(axis='x', numticks=6)  # Adjust number as needed

plt.tight_layout()
plt.savefig(f"AllenCahn-res{res}-vs-spectrum-noise-energy spectrum.pdf", dpi=300)
# Out:
# /state/partition1/job-63539340/ipykernel_3609908/2405163925.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrk = torch.load(home + f"AllenCahn-res{res}-kvals.pt")
# ...

# %%
res = 32
home = "/home/yc3400/scratch_research/gitrepo/GenerativeDynamics-NumericalDesign/Allen-Cahn/results/"
arrk = torch.load(home + f"AllenCahn-res{res}-kvals.pt")
arrtruth = torch.load(home + f"AllenCahn-res{res}-truth.pt")
arrRK10 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK10.pt") 
arrspectrumRK5 = torch.load(home + f"AllenCahn-res{res}-spectrum-noise-RK5.pt")


plt.figure(figsize=(6, 6))
markers = ['o', 's', '^', 'd', 'v']

plt.plot(arrk, arrtruth, 'o-', marker=markers[0], markersize=8, markevery=5, linestyle='-', label="truth", linewidth=2)
plt.plot(arrk, arrspectrumRK5, 'o-', marker=markers[4], markersize=8, markevery=5, linestyle='-', label="spectrum-noise-RK10steps", linewidth=2)
plt.plot(arrk, arrRK10, 'o-', marker=markers[1], markersize=8, markevery=5, linestyle='-', label="white-noise-RK10steps", linewidth=2)

# plt.xlabel("k", fontsize=12)
# plt.title("Energy spectrum", fontsize=14)
plt.legend(fontsize=16, loc='upper right')
plt.grid(alpha=0.3)
plt.xscale('log', base = 2)
plt.yscale('log')
plt.tick_params(axis='both', which='major', labelsize=20)  # Change 14 to your desired size
plt.locator_params(axis='x', numticks=5)  # Adjust number as needed

plt.tight_layout()
plt.savefig(f"AllenCahn-res{res}-vs-spectrum-noise-energy spectrum.pdf", dpi=300)
# Out:
# /state/partition1/job-63539340/ipykernel_3609908/2854768000.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrk = torch.load(home + f"AllenCahn-res{res}-kvals.pt")
# ...
