# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.utils.data
from torch.utils.data import DataLoader 
from PIL import Image
from matplotlib import pyplot as plt
import seaborn as sns
import wandb
import math
import argparse
import datetime
import math
from time import time

# %%
res = 128
home = "/home/yc3400/scratch_research/gitrepo/GenerativeDynamics-NumericalDesign/Allen-Cahn/results/"
arrk = torch.load(home + f"AllenCahn-res{res}-kvals.pt")
arrtruth = torch.load(home + f"AllenCahn-res{res}-truth.pt")
arrRK10 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK10.pt") 
arrRK20 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK20.pt") 
arrRK40 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK40.pt")
arrscaledRK10 = torch.load(home + f"AllenCahn-res{res}-scaled-schedule-RK10.pt")
# Out:
# /state/partition1/job-62391188/ipykernel_1898355/769930538.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrk = torch.load(home + f"AllenCahn-res{res}-kvals.pt")
# /state/partition1/job-62391188/ipykernel_1898355/769930538.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrtruth = torch.load(home + f"AllenCahn-res{res}-truth.pt")
# /state/partition1/job-62391188/ipykernel_1898355/769930538.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrRK10 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK10.pt")
# /state/partition1/job-62391188/ipykernel_1898355/769930538.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrRK20 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK20.pt")
# /state/partition1/job-62391188/ipykernel_1898355/769930538.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrRK40 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK40.pt")
# /state/partition1/job-62391188/ipykernel_1898355/769930538.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrscaledRK10 = torch.load(home + f"AllenCahn-res{res}-scaled-schedule-RK10.pt")

# %%
plt.figure(figsize=(6, 6))
markers = ['o', 's', '^', 'd', 'v']

plt.plot(arrk, arrtruth, 'o-', marker=markers[0], markersize=8, markevery=5, linestyle='-', label="truth", linewidth=2)
plt.plot(arrk, arrscaledRK10, 'o-', marker=markers[4], markersize=8, markevery=5, linestyle='-', label="designed-RK10steps", linewidth=2)
plt.plot(arrk, arrRK10, 'o-', marker=markers[1], markersize=8, markevery=5, linestyle='-', label="linear-RK10steps", linewidth=2)
plt.plot(arrk, arrRK20, 'o-', marker=markers[2], markersize=8, markevery=5, linestyle='-', label="linear-RK20steps", linewidth=2)
plt.plot(arrk, arrRK40, 'o-', marker=markers[3], markersize=8, markevery=5, linestyle='-', label="linear-RK40steps", linewidth=2)

# plt.xlabel("k", fontsize=12)
# plt.title("Energy spectrum", fontsize=14)
plt.legend(fontsize=14)
plt.grid(alpha=0.3)
plt.xscale('log', base = 2)
plt.yscale('log')
plt.tick_params(axis='both', which='major', labelsize=14)  # Change 14 to your desired size

plt.tight_layout()
plt.savefig(f"AllenCahn-res{res}-energy spectrum.pdf", dpi=300)
# Out:
# /state/partition1/job-62391188/ipykernel_1898355/2433736875.py:4: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(arrk, arrtruth, 'o-', marker=markers[0], markersize=8, markevery=5, linestyle='-', label="truth", linewidth=2)
# /state/partition1/job-62391188/ipykernel_1898355/2433736875.py:4: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(arrk, arrtruth, 'o-', marker=markers[0], markersize=8, markevery=5, linestyle='-', label="truth", linewidth=2)
# /state/partition1/job-62391188/ipykernel_1898355/2433736875.py:5: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(arrk, arrscaledRK10, 'o-', marker=markers[4], markersize=8, markevery=5, linestyle='-', label="designed-RK10steps", linewidth=2)
# /state/partition1/job-62391188/ipykernel_1898355/2433736875.py:5: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(arrk, arrscaledRK10, 'o-', marker=markers[4], markersize=8, markevery=5, linestyle='-', label="designed-RK10steps", linewidth=2)
# /state/partition1/job-62391188/ipykernel_1898355/2433736875.py:6: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(arrk, arrRK10, 'o-', marker=markers[1], markersize=8, markevery=5, linestyle='-', label="linear-RK10steps", linewidth=2)
# /state/partition1/job-62391188/ipykernel_1898355/2433736875.py:6: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(arrk, arrRK10, 'o-', marker=markers[1], markersize=8, markevery=5, linestyle='-', label="linear-RK10steps", linewidth=2)
# /state/partition1/job-62391188/ipykernel_1898355/2433736875.py:7: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(arrk, arrRK20, 'o-', marker=markers[2], markersize=8, markevery=5, linestyle='-', label="linear-RK20steps", linewidth=2)
# /state/partition1/job-62391188/ipykernel_1898355/2433736875.py:7: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(arrk, arrRK20, 'o-', marker=markers[2], markersize=8, markevery=5, linestyle='-', label="linear-RK20steps", linewidth=2)
# /state/partition1/job-62391188/ipykernel_1898355/2433736875.py:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(arrk, arrRK40, 'o-', marker=markers[3], markersize=8, markevery=5, linestyle='-', label="linear-RK40steps", linewidth=2)
# /state/partition1/job-62391188/ipykernel_1898355/2433736875.py:8: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(arrk, arrRK40, 'o-', marker=markers[3], markersize=8, markevery=5, linestyle='-', label="linear-RK40steps", linewidth=2)

# %%
res = 64
home = "/home/yc3400/scratch_research/gitrepo/GenerativeDynamics-NumericalDesign/Allen-Cahn/results/"
arrk = torch.load(home + f"AllenCahn-res{res}-kvals.pt")
arrtruth = torch.load(home + f"AllenCahn-res{res}-truth.pt")
arrRK10 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK10.pt") 
arrRK20 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK20.pt") 
# arrRK40 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK40.pt")
arrscaledRK10 = torch.load(home + f"AllenCahn-res{res}-scaled-schedule-RK10.pt")


plt.figure(figsize=(6, 6))
markers = ['o', 's', '^', 'd', 'v']

plt.plot(arrk, arrtruth, 'o-', marker=markers[0], markersize=8, markevery=5, linestyle='-', label="truth", linewidth=2)
plt.plot(arrk, arrscaledRK10, 'o-', marker=markers[4], markersize=8, markevery=5, linestyle='-', label="designed-RK10steps", linewidth=2)
plt.plot(arrk, arrRK10, 'o-', marker=markers[1], markersize=8, markevery=5, linestyle='-', label="linear-RK10steps", linewidth=2)
plt.plot(arrk, arrRK20, 'o-', marker=markers[2], markersize=8, markevery=5, linestyle='-', label="linear-RK20steps", linewidth=2)
# plt.plot(arrk, arrRK40, 'o-', marker=markers[3], markersize=8, markevery=5, linestyle='-', label="linear-RK40steps", linewidth=2)

# plt.xlabel("k", fontsize=12)
# plt.title("Energy spectrum", fontsize=14)
plt.legend(fontsize=14)
plt.grid(alpha=0.3)
plt.xscale('log', base = 2)
plt.yscale('log')
plt.tick_params(axis='both', which='major', labelsize=14)  # Change 14 to your desired size

plt.tight_layout()
plt.savefig(f"AllenCahn-res{res}-energy spectrum.pdf", dpi=300)
# Out:
# /state/partition1/job-62391188/ipykernel_1898355/1813829099.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrk = torch.load(home + f"AllenCahn-res{res}-kvals.pt")
# /state/partition1/job-62391188/ipykernel_1898355/1813829099.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrtruth = torch.load(home + f"AllenCahn-res{res}-truth.pt")
# /state/partition1/job-62391188/ipykernel_1898355/1813829099.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrRK10 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK10.pt")
# /state/partition1/job-62391188/ipykernel_1898355/1813829099.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrRK20 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK20.pt")
# /state/partition1/job-62391188/ipykernel_1898355/1813829099.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrscaledRK10 = torch.load(home + f"AllenCahn-res{res}-scaled-schedule-RK10.pt")
# /state/partition1/job-62391188/ipykernel_1898355/1813829099.py:14: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(arrk, arrtruth, 'o-', marker=markers[0], markersize=8, markevery=5, linestyle='-', label="truth", linewidth=2)
# /state/partition1/job-62391188/ipykernel_1898355/1813829099.py:14: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(arrk, arrtruth, 'o-', marker=markers[0], markersize=8, markevery=5, linestyle='-', label="truth", linewidth=2)
# /state/partition1/job-62391188/ipykernel_1898355/1813829099.py:15: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(arrk, arrscaledRK10, 'o-', marker=markers[4], markersize=8, markevery=5, linestyle='-', label="designed-RK10steps", linewidth=2)
# /state/partition1/job-62391188/ipykernel_1898355/1813829099.py:15: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(arrk, arrscaledRK10, 'o-', marker=markers[4], markersize=8, markevery=5, linestyle='-', label="designed-RK10steps", linewidth=2)
# /state/partition1/job-62391188/ipykernel_1898355/1813829099.py:16: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(arrk, arrRK10, 'o-', marker=markers[1], markersize=8, markevery=5, linestyle='-', label="linear-RK10steps", linewidth=2)
# /state/partition1/job-62391188/ipykernel_1898355/1813829099.py:16: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(arrk, arrRK10, 'o-', marker=markers[1], markersize=8, markevery=5, linestyle='-', label="linear-RK10steps", linewidth=2)
# /state/partition1/job-62391188/ipykernel_1898355/1813829099.py:17: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(arrk, arrRK20, 'o-', marker=markers[2], markersize=8, markevery=5, linestyle='-', label="linear-RK20steps", linewidth=2)
# /state/partition1/job-62391188/ipykernel_1898355/1813829099.py:17: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(arrk, arrRK20, 'o-', marker=markers[2], markersize=8, markevery=5, linestyle='-', label="linear-RK20steps", linewidth=2)

# %%
res = 32
home = "/home/yc3400/scratch_research/gitrepo/GenerativeDynamics-NumericalDesign/Allen-Cahn/results/"
arrk = torch.load(home + f"AllenCahn-res{res}-kvals.pt")
arrtruth = torch.load(home + f"AllenCahn-res{res}-truth.pt")
arrRK10 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK10.pt") 
# arrRK20 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK20.pt") 
# arrRK40 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK40.pt")
arrscaledRK10 = torch.load(home + f"AllenCahn-res{res}-scaled-schedule-RK10.pt")


plt.figure(figsize=(6, 6))
markers = ['o', 's', '^', 'd', 'v']

plt.plot(arrk, arrtruth, 'o-', marker=markers[0], markersize=8, markevery=5, linestyle='-', label="truth", linewidth=2)
plt.plot(arrk, arrscaledRK10, 'o-', marker=markers[4], markersize=8, markevery=5, linestyle='-', label="designed-RK10steps", linewidth=2)
plt.plot(arrk, arrRK10, 'o-', marker=markers[1], markersize=8, markevery=5, linestyle='-', label="linear-RK10steps", linewidth=2)
# plt.plot(arrk, arrRK20, 'o-', marker=markers[2], markersize=8, markevery=5, linestyle='-', label="linear-RK20steps", linewidth=2)
# plt.plot(arrk, arrRK40, 'o-', marker=markers[3], markersize=8, markevery=5, linestyle='-', label="linear-RK40steps", linewidth=2)

# plt.xlabel("k", fontsize=12)
# plt.title("Energy spectrum", fontsize=14)
plt.legend(fontsize=14)
plt.grid(alpha=0.3)
plt.xscale('log', base = 2)
plt.yscale('log')
plt.tick_params(axis='both', which='major', labelsize=14)  # Change 14 to your desired size

plt.tight_layout()
plt.savefig(f"AllenCahn-res{res}-energy spectrum.pdf", dpi=300)
# Out:
# /state/partition1/job-62391188/ipykernel_1898355/519853378.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrk = torch.load(home + f"AllenCahn-res{res}-kvals.pt")
# /state/partition1/job-62391188/ipykernel_1898355/519853378.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrtruth = torch.load(home + f"AllenCahn-res{res}-truth.pt")
# /state/partition1/job-62391188/ipykernel_1898355/519853378.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrRK10 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK10.pt")
# /state/partition1/job-62391188/ipykernel_1898355/519853378.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   arrscaledRK10 = torch.load(home + f"AllenCahn-res{res}-scaled-schedule-RK10.pt")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 8
#       5 arrRK10 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK10.pt")
#       6 # arrRK20 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK20.pt")
#       7 # arrRK40 = torch.load(home + f"AllenCahn-res{res}-standard-schedule-RK40.pt")
# ----> 8 arrscaledRK10 = torch.load(home + f"AllenCahn-res{res}-scaled-schedule-RK10.pt")
#      11 plt.figure(figsize=(6, 6))
#      12 markers = ['o', 's', '^', 'd', 'v']
#
# File /ext3/miniforge3/lib/python3.12/site-packages/torch/serialization.py:1319, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1316 if "encoding" not in pickle_load_args.keys():
#    1317     pickle_load_args["encoding"] = "utf-8"
# -> 1319 with _open_file_like(f, "rb") as opened_file:
#    1320     if _is_zipfile(opened_file):
#    1321         # The zipfile reader is going to advance the current file position.
#    1322         # If we want to actually tail call to torch.jit.load, we need to
#    1323         # reset back to the original position.
#    1324         orig_position = opened_file.tell()
#
# File /ext3/miniforge3/lib/python3.12/site-packages/torch/serialization.py:659, in _open_file_like(name_or_buffer, mode)
#     657 def _open_file_like(name_or_buffer, mode):
#     658     if _is_path(name_or_buffer):
# --> 659         return _open_file(name_or_buffer, mode)
#     660     else:
#     661         if "w" in mode:
#
# File /ext3/miniforge3/lib/python3.12/site-packages/torch/serialization.py:640, in _open_file.__init__(self, name, mode)
#     639 def __init__(self, name, mode):
# --> 640     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/yc3400/scratch_research/gitrepo/GenerativeDynamics-NumericalDesign/Allen-Cahn/results/AllenCahn-res32-scaled-schedule-RK10.pt'
